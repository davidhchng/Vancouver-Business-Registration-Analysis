# %% [markdown]
# # Business License Registration Analysis
#
# This notebook analyzes business license registration data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Load Data

# %%
# Load the business licenses data
df = pd.read_csv('business-licences.csv', delimiter=';')
print(f"Dataset shape: {df.shape[0]} rows, {df.shape[1]} columns")
df.head()

# %% [markdown]
# ## Explore Data

# %%
# Display column info
df.info()

# %%
# Check for missing values
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)

# %%
# Basic statistics
df.describe()

# %% [markdown]
# ## Your Analysis Here
#
# Add your custom analysis below!
